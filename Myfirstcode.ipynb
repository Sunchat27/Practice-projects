# %%
import pandas as pd

# %%
df = pd.read_excel("C:\SUNEET\course_curriculum_Data_Science.xlsx")

# %%
df
# Out:
#                                                 Topics Day wise
# 0                            Data Science Introduction    Day 1
# 1                                               Python      NaN
# 2                                         Introduction    Day 2
# 3                        Simple Expressions, Variables      NaN
# 4                                Data Types/structures      NaN
# ..                                                 ...      ...
# 171                                       Kmeans model   Day 39
# 172                            Hierarchical clustering   Day 40
# 173                                             DBSCAN      NaN
# 174                                                NaN      NaN
# 175  Days might vary between 2-4 days, depending on...      NaN
#
# [176 rows x 2 columns]

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Sameer'

# %%
h = pd.read_excel("practise.xlsx")

# %%
h
# Out:
#    Unnamed: 0           Unnamed: 1           Unnamed: 2           Unnamed: 3  \
# 0         NaN       MONTHLY BUDGET                  NaN                  NaN
# 1       Items  2019-01-01 00:00:00  2021-02-01 00:00:00  2018-03-01 00:00:00
# 2         car                   23                   32                  574
# 3          tv                   23                  342                   45
# 4          pc                  423                  234                   64
# 5      laptop                   43                   32                   43
# 6       water                  423                  654                  435
# 7      school                   34                  423                   54
# 8        food                   22                  435                   76
# 9       total                  991                 2152                 1291
# 10        NaN                  NaN                  NaN                  NaN
# ...
